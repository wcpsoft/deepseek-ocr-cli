# %% [markdown]
# **下载源代码**

# %%
# !git clone https://github.com/wcpsoft/deepseek-ocr-cli.git
# Out:
# Cloning into 'deepseek-ocr-cli'...
# remote: Enumerating objects: 272, done.
# remote: Counting objects: 100% (272/272), done.
# remote: Compressing objects: 100% (153/153), done.
# remote: Total 272 (delta 130), reused 259 (delta 117), pack-reused 0 (from 0)
# Receiving objects: 100% (272/272), 15.49 MiB | 6.20 MiB/s, done.
# Resolving deltas: 100% (130/130), done.

# %%
# %cd deepseek-ocr-cli
# Out:
# /content/deepseek-ocr-cli

# %%
# !curl -LsSf https://astral.sh/uv/install.sh | sh
# !uv venv --python=3.10 --clear
# !source .venv/bin/activate
# Out:
# downloading uv 0.9.5 x86_64-unknown-linux-gnu
# no checksums to verify
# installing to /usr/local/bin
#   uv
#   uvx
# everything's installed!
# ...
# Using CPython 3.10.12 interpreter at: /usr/bin/python3.10
# Creating virtual environment at: .venv
# Activate with: source .venv/bin/activate

# %%
# !git pull origin feat/m1
# Out:
# From https://github.com/wcpsoft/deepseek-ocr-cli
#  * branch            feat/m1    -> FETCH_HEAD
# Already up to date.

# %%
# !uv pip install -e .
# !./dev/run_tests.sh
# Out:
# Using Python 3.12.12 environment at: /usr
# Resolved 36 packages in 30ms
# Prepared 1 package in 908ms
# Uninstalled 1 package in 0.47ms
# Installed 1 package in 1ms
#  ~ deepseek-ocr-cli==1.0.0 (from file:///content/deepseek-ocr-cli)
# ...
#   DeepSeek OCR CLI 测试脚本
# ...
# 检测GPU环境...
# DEBUG: GPU_TYPE='nvidia'
# DEBUG: EXTRA_SUFFIX='[nvidia]'
# 安装开发依赖...
# 检测到 nvidia GPU，安装相应版本的PyTorch...
# Using Python 3.12.12 environment at: /usr
# Resolved 58 packages in 101ms
# Prepared 17 packages in 1.40s
# Uninstalled 1 package in 0.46ms
# Installed 17 packages in 33ms
#  + black==25.9.0
#  + cfgv==3.4.0
#  ~ deepseek-ocr-cli==1.0.0 (from file:///content/deepseek-ocr-cli)
#  + distlib==0.4.0
#  + flake8==7.3.0
#  + identify==2.6.15
#  + isort==7.0.0
#  + mccabe==0.7.0
#  + mypy==1.18.2
#  + mypy-extensions==1.1.0
#  + nodeenv==1.9.1
#  + pathspec==0.12.1
#  + pre-commit==4.3.0
#  + pycodestyle==2.14.0
#  + pyflakes==3.4.0
#  + pytokens==0.2.0
#  + virtualenv==20.35.3
# 安装NVIDIA GPU特定依赖...
# ...
